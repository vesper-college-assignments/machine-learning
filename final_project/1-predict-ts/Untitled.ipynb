# %%
import pandas as pd

# %%
X = pd.read_hdf('X.h5', key='X')
y = pd.read_hdf('y.h5', key='y')
X = X.set_index(['engine_no', 'time'])
X = X.drop(['index'], axis=1)

# %%
X
# Out:
#                                op_setting_1  op_setting_2  op_setting_3  \
# engine_no time
# 1.0       2000-01-01 00:00:00       -0.0007       -0.0004         100.0
#           2000-01-01 00:00:00       34.9983        0.8400         100.0
#           2000-01-01 00:00:00       -0.0005        0.0004         100.0
#           2000-01-01 00:00:00       42.0049        0.8400         100.0
#           2000-01-01 00:10:00       20.0020        0.7002         100.0
#           2000-01-01 00:10:00        0.0008       -0.0003         100.0
#           2000-01-01 00:10:00        0.0019       -0.0003         100.0
#           2000-01-01 00:10:00       41.9982        0.8408         100.0
#           2000-01-01 00:20:00       24.9988        0.6218          60.0
#           2000-01-01 00:20:00       -0.0043        0.0003         100.0
#           2000-01-01 00:20:00       42.0038        0.8409         100.0
#           2000-01-01 00:20:00       -0.0014       -0.0002         100.0
# ...

# %%
X = X.reset_index()

# %%
X.groupby(['engine_no'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-23a85978deb7> in <module>
# ----> 1 X.groupby(['engine_no'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...

# %%
X.head(1)
# Out:
#                       time  op_setting_1  op_setting_2  op_setting_3  \
# 0      2000-01-01 00:00:00       -0.0007       -0.0004         100.0
# 597    2000-01-02 00:50:00        0.0025        0.0000         100.0
# 1675   2000-01-03 21:40:00       25.0071        0.6200          60.0
# 2498   2000-01-05 08:00:00       42.0046        0.8413         100.0
# 3388   2000-01-06 21:10:00        0.0031        0.0002         100.0
# 4055   2000-01-08 00:50:00       20.0059        0.7000         100.0
# 4752   2000-01-09 06:00:00       10.0076        0.2500         100.0
# 5451   2000-01-10 11:00:00       42.0039        0.8400         100.0
# 6052   2000-01-11 12:10:00       35.0044        0.8408         100.0
# 6848   2000-01-12 21:20:00       42.0041        0.8414         100.0
# 7586   2000-01-14 04:00:00       20.0070        0.7006         100.0
# 8670   2000-01-16 01:10:00       42.0005        0.8400         100.0
# 9665   2000-01-17 18:40:00        9.9987        0.2500         100.0
# ...
