# %% [markdown]
# # Experiment 1 - Predict using XGBoost
#
# ### Notebook 2: Data Exploration and Feature engineering

# %% [markdown]
# **ToDo**
# * Padronizar os data types
# * Normalizar valores
# * Pesquisar feature engineering para serie temporal multivariada
# * Será que eu uso a feature tools? =P

# %%
import pandas as pd

# %%
data = pd.read_csv('../data/CMAPSSData/data_all.csv', index_col='index')

# %%
data.shape
# Out:
# (160359, 30)

# %%
data.head(3)
# Out:
#        Unnamed: 0  engine_no  time_in_cycles  op_setting_1  op_setting_2  \
# index
# 0               0          1               1       -0.0007       -0.0004
# 1               1          1               2        0.0019       -0.0003
# 2               2          1               3       -0.0043        0.0003
#
#        op_setting_3  sensor_meas_1  sensor_meas_2  sensor_meas_3  \
# index
# 0             100.0         518.67         641.82        1589.70
# 1             100.0         518.67         642.15        1591.82
# 2             100.0         518.67         642.35        1587.99
#
#        sensor_meas_4  ...  sensor_meas_15  sensor_meas_16  sensor_meas_17  \
# index                 ...
# 0            1400.60  ...          8.4195            0.03             392
# 1            1403.14  ...          8.4318            0.03             392
# 2            1404.20  ...          8.4178            0.03             390
#
# ...

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# trocar time por datetime
time = pd.to_datetime(data['time'])
data.drop(['time'], axis=1, inplace=True)
data = pd.concat([data, time], axis=1)

# %%
# trocar int por float
for col in ['engine_no', 'time_in_cycles', 'sensor_meas_17','sensor_meas_18', 'engine_family']:
    ints = data[col].astype('float64')
    data.drop([col], axis=1, inplace=True)
    data = pd.concat([data, ints], axis=1)

# %%
# Ordenar por timestamp

# %%
# Separar o target
#y = data['RUL']

# %%
data.head(3)
# Out:
#        op_setting_1  op_setting_2  op_setting_3  sensor_meas_1  sensor_meas_2  \
# index
# 0           -0.0007       -0.0004         100.0         518.67         641.82
# 1            0.0019       -0.0003         100.0         518.67         642.15
# 2           -0.0043        0.0003         100.0         518.67         642.35
#
#        sensor_meas_3  sensor_meas_4  sensor_meas_5  sensor_meas_6  \
# index
# 0            1589.70        1400.60          14.62          21.61
# 1            1591.82        1403.14          14.62          21.61
# 2            1587.99        1404.20          14.62          21.61
#
#        sensor_meas_7  ...  sensor_meas_19  sensor_meas_20  sensor_meas_21  \
# index                 ...
# 0             554.36  ...           100.0           39.06         23.4190
# 1             553.75  ...           100.0           39.00         23.4236
# 2             554.26  ...           100.0           38.95         23.3442
#
# ...

# %%
data.dtypes
# Out:
# op_setting_1             float64
# op_setting_2             float64
# op_setting_3             float64
# sensor_meas_1            float64
# sensor_meas_2            float64
# sensor_meas_3            float64
# sensor_meas_4            float64
# sensor_meas_5            float64
# sensor_meas_6            float64
# sensor_meas_7            float64
# sensor_meas_8            float64
# sensor_meas_9            float64
# sensor_meas_10           float64
# sensor_meas_11           float64
# sensor_meas_12           float64
# sensor_meas_13           float64
# sensor_meas_14           float64
# sensor_meas_15           float64
# sensor_meas_16           float64
# sensor_meas_19           float64
# sensor_meas_20           float64
# sensor_meas_21           float64
# RUL                      float64
# time              datetime64[ns]
# engine_no                float64
# time_in_cycles           float64
# sensor_meas_17           float64
# sensor_meas_18           float64
# ...

# %% [markdown]
# **Date/time features**

# %%
data.describe()
# Out:
#         op_setting_1   op_setting_2   op_setting_3  sensor_meas_1  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean       17.211973       0.410004      95.724344     485.840890
# std        16.527988       0.367938      12.359044      30.420388
# min        -0.008700      -0.000600      60.000000     445.000000
# 25%         0.001300       0.000200     100.000000     449.440000
# 50%        19.998100       0.620000     100.000000     489.050000
# 75%        35.001500       0.840000     100.000000     518.670000
# max        42.008000       0.842000     100.000000     518.670000
#
#        sensor_meas_2  sensor_meas_3  sensor_meas_4  sensor_meas_5  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean      597.361022    1467.035653    1260.956434       9.894999
# std        42.478516     118.175261     136.300073       4.265554
# min       535.480000    1242.670000    1023.770000       3.910000
# ...

# %% [markdown]
# **
