# %% [markdown]
# # Experiment 1 - Predict using XGBoost
#
# ### Notebook 3: Data exploration and preparation

# %% [markdown]
# **ToDo**
# * Como transformar de uma lista de timestamps para um DF 2D?

# %%
import pandas as pd
from sklearn.preprocessing import minmax_scale

# %%
X = pd.read_hdf('X.h5', key='X')
y = pd.read_hdf('y.h5', key='y')
X = X.set_index('time')
X = X.drop(['index'], axis=1)

# %%
X.head(5)
# Out:
#                      op_setting_1  op_setting_2  op_setting_3  sensor_meas_1  \
# time
# 2000-01-01 00:00:00       -0.0007       -0.0004         100.0         518.67
# 2000-01-01 00:00:00       34.9983        0.8400         100.0         449.44
# 2000-01-01 00:00:00       -0.0005        0.0004         100.0         518.67
# 2000-01-01 00:00:00       42.0049        0.8400         100.0         445.00
# 2000-01-01 00:10:00       20.0020        0.7002         100.0         491.19
#
#                      sensor_meas_2  sensor_meas_3  sensor_meas_4  \
# time
# 2000-01-01 00:00:00         641.82        1589.70        1400.60
# 2000-01-01 00:00:00         555.32        1358.61        1137.23
# 2000-01-01 00:00:00         642.36        1583.23        1396.84
# 2000-01-01 00:00:00         549.68        1343.43        1112.93
# 2000-01-01 00:10:00         606.07        1477.61        1237.50
#
#                      sensor_meas_5  sensor_meas_6  sensor_meas_7  ...  \
# ...

# %%
X.describe()
# Out:
#         op_setting_1   op_setting_2   op_setting_3  sensor_meas_1  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean       17.211973       0.410004      95.724344     485.840890
# std        16.527988       0.367938      12.359044      30.420388
# min        -0.008700      -0.000600      60.000000     445.000000
# 25%         0.001300       0.000200     100.000000     449.440000
# 50%        19.998100       0.620000     100.000000     489.050000
# 75%        35.001500       0.840000     100.000000     518.670000
# max        42.008000       0.842000     100.000000     518.670000
#
#        sensor_meas_2  sensor_meas_3  sensor_meas_4  sensor_meas_5  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean      597.361022    1467.035653    1260.956434       9.894999
# std        42.478516     118.175261     136.300073       4.265554
# min       535.480000    1242.670000    1023.770000       3.910000
# ...

# %% [markdown]
# Os valores estão em ranges muito diferentes. Será necessário normalizar os valores

# %%
X.dtypes
# Out:
# op_setting_1      float64
# op_setting_2      float64
# op_setting_3      float64
# sensor_meas_1     float64
# sensor_meas_2     float64
# sensor_meas_3     float64
# sensor_meas_4     float64
# sensor_meas_5     float64
# sensor_meas_6     float64
# sensor_meas_7     float64
# sensor_meas_8     float64
# sensor_meas_9     float64
# sensor_meas_10    float64
# sensor_meas_11    float64
# sensor_meas_12    float64
# sensor_meas_13    float64
# sensor_meas_14    float64
# sensor_meas_15    float64
# sensor_meas_16    float64
# sensor_meas_19    float64
# sensor_meas_20    float64
# sensor_meas_21    float64
# engine_no         float64
# time_in_cycles    float64
# sensor_meas_17    float64
# sensor_meas_18    float64
# engine_family     float64
# dtype: object

# %%
for col in X.columns:
    print(col, " has ", X[col].unique().shape[0], "uniques")
# Out:
# op_setting_1  has  670 uniques
# op_setting_2  has  111 uniques
# op_setting_3  has  2 uniques
# sensor_meas_1  has  6 uniques
# sensor_meas_2  has  1799 uniques
# sensor_meas_3  has  15377 uniques
# sensor_meas_4  has  20582 uniques
# sensor_meas_5  has  6 uniques
# sensor_meas_6  has  56 uniques
# sensor_meas_7  has  6311 uniques
# sensor_meas_8  has  1163 uniques
# sensor_meas_9  has  34161 uniques
# sensor_meas_10  has  21 uniques
# sensor_meas_11  has  771 uniques
# sensor_meas_12  has  5982 uniques
# sensor_meas_13  has  567 uniques
# sensor_meas_14  has  20090 uniques
# sensor_meas_15  has  13124 uniques
# sensor_meas_16  has  2 uniques
# sensor_meas_19  has  2 uniques
# sensor_meas_20  has  676 uniques
# sensor_meas_21  has  26659 uniques
# engine_no  has  260 uniques
# time_in_cycles  has  543 uniques
# sensor_meas_17  has  58 uniques
# sensor_meas_18  has  6 uniques
# engine_family  has  4 uniques

# %%
X['engine_no'].unique().shape
# Out:
# (260,)

# %%
X.isnull().values.any()
# Out:
# False

# %%
# Normalização das features
X = pd.DataFrame(minmax_scale(X, feature_range=(0, 1)))
X.describe()
# Out:
#                   0              1              2              3   \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean        0.409853       0.487306       0.893109       0.554376
# std         0.393367       0.436670       0.308976       0.412928
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000238       0.000949       1.000000       0.060269
# 50%         0.476163       0.736530       1.000000       0.597937
# 75%         0.833245       0.997626       1.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                   4              5              6              7   \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean        0.564453       0.599523       0.567812       0.558823
# std         0.387472       0.315774       0.326295       0.398278
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### Visualização das séries

# %%
# create a line plot for each variable

x_axis = X[1]

pyplot.figure()

# %%
X.shape[1]
# Out:
# 27

# %%
# plot inputs for a chunk
from numpy import unique
from pandas import read_csv
from matplotlib import pyplot

def plot_chunk_inputs(values, c_ids):
    pyplot.figure()
    
    # n features
    inputs = range(27)
    
    for i in range(len(inputs)):
        ax = pyplot.subplot(len(inputs), 1, i+1)
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        column = inputs[i]
        rows = values
        pyplot.plot(rows[:,column])
    pyplot.show()

# group data by chunks
values = X.values

# plot inputs for some chunks

plot_chunk_inputs(values, [1])
